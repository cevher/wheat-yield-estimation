# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_excel('wheat_data.xlsx', index_col=0)
data2 = pd.read_excel('wheat_data.xlsx', index_col=0)
data.head()
# Out:
#       Yield  Production Amount  Nitrogen (N)  Phosphorous (P2O5)  \
# Year
# 2004    220             380867    67576.2700           30445.530
# 2005    291             456434    65453.6900           28306.070
# 2006    296             484943    70153.3800           31615.415
# 2007    324             487968    84170.3325           30741.160
# 2008    279             386488    79907.5678           20778.590
#
#       POTASH (K2O)  September Average Minimum Temperature  \
# Year
# 2004      154.9500                                   20.2
# 2005      330.2200                                   20.7
# 2006      167.3100                                   19.8
# 2007      896.1200                                   21.0
# 2008     1104.0722                                   22.0
#
#       October Average Minimum Temperature  \
# Year
# 2004                                 16.0
# 2005                                 16.5
# 2006                                 13.2
# ...
